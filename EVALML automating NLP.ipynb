# %%
from urllib.request import urlopen
import pandas as pd

input_data = urlopen('https://featurelabs-static.s3.amazonaws.com/spam_text_messages_modified.csv')
data = pd.read_csv(input_data)
data.head()
# Out:
#   Category                                            Message
# 0     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 1     spam  FreeMsg Hey there darling it's been 3 week's n...
# 2     spam  WINNER!! As a valued network customer you have...
# 3     spam  Had your mobile 11 months or more? U R entitle...
# 4     spam  SIX chances to win CASH! From 100 to 20,000 po...

# %%
X=data.drop('Category',axis=1)
y=data['Category']

# %%
X.head(50)
# Out:
#                                               Message
# 0   Free entry in 2 a wkly comp to win FA Cup fina...
# 1   FreeMsg Hey there darling it's been 3 week's n...
# 2   WINNER!! As a valued network customer you have...
# 3   Had your mobile 11 months or more? U R entitle...
# 4   SIX chances to win CASH! From 100 to 20,000 po...
# 5   URGENT! You have won a 1 week FREE membership ...
# 6   XXXMobileMovieClub: To use your credit, click ...
# 7   England v Macedonia - dont miss the goals/team...
# 8   Thanks for your subscription to Ringtone UK yo...
# 9   07732584351 - Rodger Burns - MSG = We tried to...
# 10  SMS. ac Sptv: The New Jersey Devils and the De...
# 11  Congrats! 1 year special cinema pass for 2 is ...
# 12  As a valued customer, I am pleased to advise y...
# 13  Urgent UR awarded a complimentary trip to Euro...
# 14  Did you hear about the new "Divorce Barbie"? I...
# 15  Please call our customer service representativ...
# 16  Your free ringtone is waiting to be collected....
# 17  GENT! We are trying to contact you. Last weeke...
# 18  You are a winner U have been specially selecte...
# 19  PRIVATE! Your 2004 Account Statement for 07742...
# 20  URGENT! Your Mobile No. was awarded £2000 Bonu...
# 21  Todays Voda numbers ending 7548 are selected t...
# 22  Sunshine Quiz Wkly Q! Win a top Sony DVD playe...
# 23  Want 2 get laid tonight? Want real Dogging loc...
# 24  You'll not rcv any more msgs from the chat svc...
# 25  FreeMsg Why haven't you replied to my text? I'...
# 26  Customer service annoncement. You have a New Y...
# 27  You are a winner U have been specially selecte...
# 28  -PLS STOP bootydelious (32/F) is inviting you ...
# 29  BangBabes Ur order is on the way. U SHOULD rec...
# 30  URGENT! We are trying to contact you. Last wee...
# 31  Please call our customer service representativ...
# 32  Are you unique enough? Find out from 30th Augu...
# 33  500 New Mobiles from 2004, MUST GO! Txt: NOKIA...
# 34  Will u meet ur dream partner soon? Is ur caree...
# 35  Text & meet someone sexy today. U can find a d...
# 36  U 447801259231 have a secret admirer who is lo...
# 37  Congratulations ur awarded 500 of CD vouchers ...
# 38  We tried to contact you re your reply to our o...
# 39  Hey I am really horny want to chat or see me n...
# 40  Ur ringtone service has changed! 25 Free credi...
# 41  Ringtone Club: Get the UK singles chart on you...
# 42  HMV BONUS SPECIAL 500 pounds of genuine HMV vo...
# 43  T-Mobile customer you may now claim your FREE ...
# 44  SMS. ac Blind Date 4U!: Rodds1 is 21/m from Ab...
# 45  TheMob> Check out our newest selection of cont...
# 46  Think ur smart ? Win £200 this week in our wee...
# 47  December only! Had your mobile 11mths+? You ar...
# 48  Call Germany for only 1 pence per minute! Call...
# 49  Valentines Day Special! Win over £1000 in our ...

# %%
y.value_counts(normalize=True)
# Out:
# ham     0.750084
# spam    0.249916
# Name: Category, dtype: float64

# %%
import evalml

# %%
X_train,X_test,y_train,y_test=evalml.preprocessing.split_data(X,y,problem_type='binary')

# %%
evalml.problem_types.ProblemTypes.all_problem_types
# Out:
# [<ProblemTypes.BINARY: 'binary'>,
#  <ProblemTypes.MULTICLASS: 'multiclass'>,
#  <ProblemTypes.REGRESSION: 'regression'>,
#  <ProblemTypes.TIME_SERIES_REGRESSION: 'time series regression'>,
#  <ProblemTypes.TIME_SERIES_BINARY: 'time series binary'>,
#  <ProblemTypes.TIME_SERIES_MULTICLASS: 'time series multiclass'>]

# %%
X_train.head()
# Out:
#                                                 Message
# 562       Haha I heard that, text me when you're around
# 1253  I'm thinking that chennai forgot to come for a...
# 1816  Can you tell Shola to please go to college of ...
# 2054                         K k pa Had your lunch aha.
# 511   staff.science.nus.edu.sg/~phyhcmk/teaching/pc1323

# %%
from evalml import AutoMLSearch

# %%
automl=AutoMLSearch(X_train=X_train,y_train=y_train,problem_type='binary',max_batches=1,optimize_thresholds=True)

# %%
automl.search()

# %%
automl.rankings
# Out:
#    id                                      pipeline_name  search_order  \
# 0   2  Random Forest Classifier w/ Label Encoder + Na...             2
# 1   1  Logistic Regression Classifier w/ Label Encode...             1
# 2   0       Mode Baseline Binary Classification Pipeline             0
#
#    mean_cv_score  standard_deviation_cv_score  validation_score  \
# 0       0.130812                     0.036607          0.130812
# 1       0.204526                     0.067735          0.204526
# 2       8.638305                     0.025020          8.638305
#
#    percent_better_than_baseline  high_variance_cv  \
# 0                     98.485679             False
# 1                     97.632337             False
# 2                      0.000000             False
#
#                                           parameters
# 0  {'Label Encoder': {'positive_label': None}, 'I...
# 1  {'Label Encoder': {'positive_label': None}, 'I...
# 2  {'Label Encoder': {'positive_label': None}, 'B...

# %%
automl.best_pipeline
# Out:
# pipeline = BinaryClassificationPipeline(component_graph={'Label Encoder': ['Label Encoder', 'X', 'y'], 'Natural Language Featurizer': ['Natural Language Featurizer', 'X', 'Label Encoder.y'], 'Imputer': ['Imputer', 'Natural Language Featurizer.x', 'Label Encoder.y'], 'Random Forest Classifier': ['Random Forest Classifier', 'Imputer.x', 'Label Encoder.y']}, parameters={'Label Encoder':{'positive_label': None}, 'Imputer':{'categorical_impute_strategy': 'most_frequent', 'numeric_impute_strategy': 'mean', 'boolean_impute_strategy': 'most_frequent', 'categorical_fill_value': None, 'numeric_fill_value': None, 'boolean_fill_value': None}, 'Random Forest Classifier':{'n_estimators': 100, 'max_depth': 6, 'n_jobs': -1}}, random_seed=0)

# %%
best_pipeline = automl.best_pipeline

# %%
automl.describe_pipeline(automl.rankings.iloc[0]["id"])
# Out:
# *************************************************************************************
# * Random Forest Classifier w/ Label Encoder + Natural Language Featurizer + Imputer *
# *************************************************************************************
#
# Problem Type: binary
# Model Family: Random Forest
#
# Pipeline Steps
# ==============
# 1. Label Encoder
# 	 * positive_label : None
# 2. Natural Language Featurizer
# 3. Imputer
# 	 * categorical_impute_strategy : most_frequent
# 	 * numeric_impute_strategy : mean
# 	 * boolean_impute_strategy : most_frequent
# 	 * categorical_fill_value : None
# 	 * numeric_fill_value : None
# 	 * boolean_fill_value : None
# 4. Random Forest Classifier
# 	 * n_estimators : 100
# 	 * max_depth : 6
# 	 * n_jobs : -1
#
# Training
# ========
# Training for binary problems.
# Total training time (including CV): 34.7 seconds
#
# Cross Validation
# ----------------
#              Log Loss Binary  MCC Binary  Gini   AUC  Precision    F1  Balanced Accuracy Binary  Accuracy Binary # Training # Validation
# 0                      0.099       0.923 0.988 0.994      0.944 0.942                     0.961            0.971      1,594          797
# 1                      0.123       0.856 0.973 0.987      0.871 0.892                     0.935            0.945      1,594          797
# 2                      0.171       0.869 0.956 0.978      0.913 0.901                     0.931            0.951      1,594          797
# mean                   0.131       0.882 0.972 0.986      0.909 0.912                     0.942            0.956          -            -
# std                    0.037       0.036 0.016 0.008      0.037 0.027                     0.016            0.014          -            -
# coef of var            0.280       0.040 0.016 0.008      0.041 0.029                     0.017            0.014          -            -

# %%
scores = best_pipeline.score(X_test, y_test,  objectives=evalml.objectives.get_core_objectives('binary'))
print(f'Accuracy Binary: {scores["Accuracy Binary"]}')
# Out:
# Accuracy Binary: 0.9765886287625418
