# %%
import evalml

# %%
X, y = evalml.demos.load_breast_cancer()
X_train, X_test, y_train, y_test = evalml.preprocessing.split_data(X, y, problem_type='binary')
# Out:
#          Number of Features
# Numeric                  30
#
# Number of training examples: 569
# Targets
# benign       62.74%
# malignant    37.26%
# Name: target, dtype: object

# %%
X_train.head()
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 381        11.04         14.93           70.67      372.7          0.07987
# 144        10.75         14.97           68.26      355.3          0.07793
# 136        11.71         16.67           74.72      423.6          0.10510
# 116         8.95         15.76           58.74      245.2          0.09462
# 567        20.60         29.33          140.10     1265.0          0.11780
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 381           0.07079         0.03546             0.020740         0.2003
# 144           0.05139         0.02251             0.007875         0.1399
# 136           0.06095         0.03592             0.026000         0.1339
# 116           0.12430         0.09263             0.023080         0.1305
# 567           0.27700         0.35140             0.152000         0.2397
#
#      mean fractal dimension  ...  worst radius  worst texture  \
# 381                 0.06246  ...        12.090          20.83
# 144                 0.05688  ...        11.950          20.72
# 136                 0.05945  ...        13.330          25.48
# 116                 0.07163  ...         9.414          17.07
# 567                 0.07016  ...        25.740          39.42
#
#      worst perimeter  worst area  worst smoothness  worst compactness  \
# 381            79.73       447.1            0.1095             0.1982
# 144            77.79       441.2            0.1076             0.1223
# 136            86.16       546.7            0.1271             0.1028
# 116            63.34       270.0            0.1179             0.1879
# 567           184.60      1821.0            0.1650             0.8681
#
#      worst concavity  worst concave points  worst symmetry  \
# 381          0.15530               0.06754          0.3202
# 144          0.09755               0.03413          0.2300
# 136          0.10460               0.06968          0.1712
# 116          0.15440               0.03846          0.1652
# 567          0.93870               0.26500          0.4087
#
#      worst fractal dimension
# 381                  0.07287
# 144                  0.06769
# 136                  0.07343
# 116                  0.07722
# 567                  0.12400
#
# [5 rows x 30 columns]

# %%
import evalml
evalml.problem_types.ProblemTypes.all_problem_types
# Out:
# [<ProblemTypes.BINARY: 'binary'>,
#  <ProblemTypes.MULTICLASS: 'multiclass'>,
#  <ProblemTypes.REGRESSION: 'regression'>,
#  <ProblemTypes.TIME_SERIES_REGRESSION: 'time series regression'>,
#  <ProblemTypes.TIME_SERIES_BINARY: 'time series binary'>,
#  <ProblemTypes.TIME_SERIES_MULTICLASS: 'time series multiclass'>]

# %%
from evalml.automl import AutoMLSearch
automl = AutoMLSearch(X_train=X_train, y_train=y_train, problem_type='binary')
automl.search()
# Out:
# 	High coefficient of variation (cv >= 0.5) within cross validation scores.
# 	Decision Tree Classifier w/ Label Encoder + Imputer + Select Columns Transformer may not perform as estimated on unseen data.

# %%
automl.rankings
# Out:
#     id                                      pipeline_name  search_order  \
# 0    1  Logistic Regression Classifier w/ Label Encode...             1
# 1    3  Logistic Regression Classifier w/ Label Encode...             3
# 2    8  Elastic Net Classifier w/ Label Encoder + Impu...             8
# 3    2  Random Forest Classifier w/ Label Encoder + Im...             2
# 4    4  Random Forest Classifier w/ Label Encoder + Im...             4
# 5   10  XGBoost Classifier w/ Label Encoder + Imputer ...            10
# 6    7  Extra Trees Classifier w/ Label Encoder + Impu...             7
# 7    6  LightGBM Classifier w/ Label Encoder + Imputer...             6
# 8    9  CatBoost Classifier w/ Label Encoder + Imputer...             9
# 9    5  Decision Tree Classifier w/ Label Encoder + Im...             5
# 10   0       Mode Baseline Binary Classification Pipeline             0
#
#     mean_cv_score  standard_deviation_cv_score  validation_score  \
# 0        0.086498                     0.024840          0.086498
# 1        0.094656                     0.042465          0.094656
# 2        0.114153                     0.031724          0.114153
# 3        0.122844                     0.018427          0.122844
# 4        0.126770                     0.035172          0.126770
# 5        0.149072                     0.054175          0.149072
# 6        0.150551                     0.034153          0.150551
# 7        0.194301                     0.052339          0.194301
# 8        0.551965                     0.005501          0.551965
# 9        2.513929                     1.035988          2.513929
# 10      12.904388                     0.082537         12.904388
#
#     percent_better_than_baseline  high_variance_cv  \
# 0                      99.329702             False
# 1                      99.266484             False
# 2                      99.115391             False
# 3                      99.048042             False
# 4                      99.017624             False
# 5                      98.844798             False
# 6                      98.833334             False
# 7                      98.494306             False
# 8                      95.722660             False
# 9                      80.518803              True
# 10                      0.000000             False
#
#                                            parameters
# 0   {'Label Encoder': {'positive_label': None}, 'I...
# 1   {'Label Encoder': {'positive_label': None}, 'I...
# 2   {'Label Encoder': {'positive_label': None}, 'I...
# 3   {'Label Encoder': {'positive_label': None}, 'I...
# 4   {'Label Encoder': {'positive_label': None}, 'I...
# 5   {'Label Encoder': {'positive_label': None}, 'I...
# 6   {'Label Encoder': {'positive_label': None}, 'I...
# 7   {'Label Encoder': {'positive_label': None}, 'I...
# 8   {'Label Encoder': {'positive_label': None}, 'I...
# 9   {'Label Encoder': {'positive_label': None}, 'I...
# 10  {'Label Encoder': {'positive_label': None}, 'B...

# %%
automl.best_pipeline
# Out:
# pipeline = BinaryClassificationPipeline(component_graph={'Label Encoder': ['Label Encoder', 'X', 'y'], 'Imputer': ['Imputer', 'X', 'Label Encoder.y'], 'Standard Scaler': ['Standard Scaler', 'Imputer.x', 'Label Encoder.y'], 'Logistic Regression Classifier': ['Logistic Regression Classifier', 'Standard Scaler.x', 'Label Encoder.y']}, parameters={'Label Encoder':{'positive_label': None}, 'Imputer':{'categorical_impute_strategy': 'most_frequent', 'numeric_impute_strategy': 'mean', 'boolean_impute_strategy': 'most_frequent', 'categorical_fill_value': None, 'numeric_fill_value': None, 'boolean_fill_value': None}, 'Logistic Regression Classifier':{'penalty': 'l2', 'C': 1.0, 'n_jobs': -1, 'multi_class': 'auto', 'solver': 'lbfgs'}}, random_seed=0)

# %%
best_pipeline=automl.best_pipeline

# %%
automl.describe_pipeline(automl.rankings.iloc[0]["id"])
# Out:
# *******************************************************************************
# * Logistic Regression Classifier w/ Label Encoder + Imputer + Standard Scaler *
# *******************************************************************************
#
# Problem Type: binary
# Model Family: Linear
#
# Pipeline Steps
# ==============
# 1. Label Encoder
# 	 * positive_label : None
# 2. Imputer
# 	 * categorical_impute_strategy : most_frequent
# 	 * numeric_impute_strategy : mean
# 	 * boolean_impute_strategy : most_frequent
# 	 * categorical_fill_value : None
# 	 * numeric_fill_value : None
# 	 * boolean_fill_value : None
# 3. Standard Scaler
# 4. Logistic Regression Classifier
# 	 * penalty : l2
# 	 * C : 1.0
# 	 * n_jobs : -1
# 	 * multi_class : auto
# 	 * solver : lbfgs
#
# Training
# ========
# Training for binary problems.
# Total training time (including CV): 12.0 seconds
#
# Cross Validation
# ----------------
#              Log Loss Binary  MCC Binary  Gini   AUC  Precision    F1  Balanced Accuracy Binary  Accuracy Binary # Training # Validation
# 0                      0.058       0.958 0.994 0.997      0.966 0.974                     0.981            0.980        303          152
# 1                      0.106       0.945 0.980 0.990      0.949 0.966                     0.975            0.974        303          152
# 2                      0.096       0.958 0.986 0.993      1.000 0.972                     0.973            0.980        304          151
# mean                   0.086       0.954 0.987 0.993      0.972 0.971                     0.976            0.978          -            -
# std                    0.025       0.008 0.007 0.004      0.026 0.004                     0.004            0.004          -            -
# coef of var            0.287       0.008 0.007 0.004      0.027 0.005                     0.004            0.004          -            -

# %%
best_pipeline.score(X_test, y_test, objectives=["auc","f1","Precision","Recall"])
# Out:
# OrderedDict([('AUC', 0.9923941798941799),
#              ('F1', 0.962962962962963),
#              ('Precision', 1.0),
#              ('Recall', 0.9285714285714286)])

# %%
automl_auc = AutoMLSearch(X_train=X_train, y_train=y_train,
                          problem_type='binary',
                          objective='auc',
                          additional_objectives=['f1', 'precision'],
                          max_batches=1,
                          optimize_thresholds=True)

automl_auc.search()

# %%
automl_auc.rankings
# Out:
#    id                                      pipeline_name  search_order  \
# 0   1  Logistic Regression Classifier w/ Label Encode...             1
# 1   2  Random Forest Classifier w/ Label Encoder + Im...             2
# 2   0       Mode Baseline Binary Classification Pipeline             0
#
#    mean_cv_score  standard_deviation_cv_score  validation_score  \
# 0       0.993310                     0.003531          0.993310
# 1       0.991616                     0.004007          0.991616
# 2       0.500000                     0.000000          0.500000
#
#    percent_better_than_baseline  high_variance_cv  \
# 0                     49.331003             False
# 1                     49.161610             False
# 2                      0.000000             False
#
#                                           parameters
# 0  {'Label Encoder': {'positive_label': None}, 'I...
# 1  {'Label Encoder': {'positive_label': None}, 'I...
# 2  {'Label Encoder': {'positive_label': None}, 'B...

# %%
automl_auc.describe_pipeline(automl_auc.rankings.iloc[0]["id"])
# Out:
# *******************************************************************************
# * Logistic Regression Classifier w/ Label Encoder + Imputer + Standard Scaler *
# *******************************************************************************
#
# Problem Type: binary
# Model Family: Linear
#
# Pipeline Steps
# ==============
# 1. Label Encoder
# 	 * positive_label : None
# 2. Imputer
# 	 * categorical_impute_strategy : most_frequent
# 	 * numeric_impute_strategy : mean
# 	 * boolean_impute_strategy : most_frequent
# 	 * categorical_fill_value : None
# 	 * numeric_fill_value : None
# 	 * boolean_fill_value : None
# 3. Standard Scaler
# 4. Logistic Regression Classifier
# 	 * penalty : l2
# 	 * C : 1.0
# 	 * n_jobs : -1
# 	 * multi_class : auto
# 	 * solver : lbfgs
#
# Training
# ========
# Training for binary problems.
# Total training time (including CV): 6.5 seconds
#
# Cross Validation
# ----------------
#               AUC    F1  Precision # Training # Validation
# 0           0.997 0.974      0.966        303          152
# 1           0.990 0.966      0.949        303          152
# 2           0.993 0.972      1.000        304          151
# mean        0.993 0.971      0.972          -            -
# std         0.004 0.004      0.026          -            -
# coef of var 0.004 0.005      0.027          -            -

# %%
best_pipeline_auc = automl_auc.best_pipeline

# %%
best_pipeline_auc.score(X_test, y_test,  objectives=["auc"])
# Out:
# OrderedDict([('AUC', 0.9923941798941799)])
